# %%
d = { 2*k : "Francesco" for k in range(10)}
for k in range(10):
   print d.get(k, "Dimiccoli")
# Out:
# Francesco
# Dimiccoli
# Francesco
# Dimiccoli
# Francesco
# Dimiccoli
# Francesco
# Dimiccoli
# Francesco
# Dimiccoli

# %%
import ROOT
tfile = ROOT.TFile("/storage/gpfs_ams/ams/users/kostya/AMSNotebook/Franceso_Plots_New/pfluxtime.root")
list(tfile.GetListOfKeys())
# Out:
# [<ROOT.TKey object ("Protons Fluxes Ratio") at 0x653a030>]

# %%
c=tfile.Get("Protons Fluxes Ratio")

# %%
c
# Out:
# <ROOT.TCanvas object ("Protons Fluxes Ratio") at 0x6511b50>

# %%
c.Draw()
